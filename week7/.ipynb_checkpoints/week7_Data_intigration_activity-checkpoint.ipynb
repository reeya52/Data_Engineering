# %%
import pandas as pd

# df_covid_data = pd.read_csv('COVID_county_data.csv')
df_asc_data = pd.read_csv('acs2017_census_tract_data.csv', usecols = ['County', 'State', 'TotalPop', 'Poverty', 'IncomePerCap', 'TractId'])

# df_covid_data
county_info = df = df_asc_data.drop_duplicates(subset=['County','State'], keep="first")
county_info
# Out:
#            TractId        State               County  TotalPop  IncomePerCap  \
# 0       1001020100      Alabama       Autauga County      1845       33018.0
# 12      1003010100      Alabama       Baldwin County      3988       21056.0
# 44      1005950100      Alabama       Barbour County      3071       20156.0
# 53      1007010001      Alabama          Bibb County      2643       20625.0
# 57      1009050101      Alabama        Blount County      7532       22599.0
# ...            ...          ...                  ...       ...           ...
# 73958  72145560100  Puerto Rico  Vega Baja Municipio      3664        7872.0
# 73972  72147950500  Puerto Rico    Vieques Municipio      4516       11435.0
# 73975  72149720100  Puerto Rico   Villalba Municipio      4553        8110.0
# 73981  72151950600  Puerto Rico    Yabucoa Municipio      6078       10255.0
# 73990  72153750101  Puerto Rico      Yauco Municipio      2462        4918.0
#
#        Poverty
# 0         10.7
# ...

# %%
rslt_df = county_info[county_info['County'] == 'Loudoun County']
print(rslt_df)
# Out:
#            TractId     State          County  TotalPop  IncomePerCap  Poverty
# 68452  51107610101  Virginia  Loudoun County      4658       46578.0      3.1
